# %%
import os 
import re
import json
import numpy as np
import pandas as pd
from requests import Session
from requests.auth import HTTPBasicAuth
from zeep import Client, Settings, Plugin, helpers
from zeep.transports import Transport
from zeep.exceptions import Fault
import logging

# %%
user = 'administrator'
passwd = 'dCloud123!'
cucm = '198.18.133.3'

DEBUG = False
WSDL_FILE = 'AXLAPI.wsdl'
logging.getLogger('zeep').setLevel(logging.ERROR)

session = Session()
session.verify=False
session.auth = HTTPBasicAuth( user,passwd )
transport = Transport( session = session, timeout = 10 )
settings = Settings( strict = False, xml_huge_tree = True )
client = Client( WSDL_FILE, settings = settings, transport = transport)
service = client.create_service( '{http://www.cisco.com/AXLAPIService/}AXLAPIBinding',f'https://{cucm}:8443/axl/')

# %%
service.getPhone(name='SEP123212321290')
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host '198.18.133.3'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
#     'return': {
#         'phone': {
#             'name': 'SEP123212321290',
#             'description': 'SEP123212321290',
#             'product': 'Cisco 8945',
#             'model': 'Cisco 8945',
#             'class': 'Phone',
#             'protocol': 'SCCP',
#             'protocolSide': 'User',
#             'callingSearchSpaceName': {
#                 '_value_1': None,
#                 'uuid': None
#             },
#             'devicePoolName': {
#                 '_value_1': 'dCloud_DP',
#                 'uuid': '{1B1B9EB6-7803-11D3-BDF0-00108302EAD1}'
#             },
#             'commonDeviceConfigName': {
#                 '_value_1': None,
# ...

# %%
service.getPhone(name="SEP123212321299")
# Out:
# /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host '198.18.133.3'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {
#     'return': {
#         'phone': {
#             'name': 'SEP123212321299',
#             'description': None,
#             'product': 'Cisco 8945',
#             'model': 'Cisco 8945',
#             'class': 'Phone',
#             'protocol': 'SIP',
#             'protocolSide': 'User',
#             'callingSearchSpaceName': {
#                 '_value_1': None,
#                 'uuid': None
#             },
#             'devicePoolName': {
#                 '_value_1': 'dCloud_DP',
#                 'uuid': '{1B1B9EB6-7803-11D3-BDF0-00108302EAD1}'
#             },
#             'commonDeviceConfigName': {
#                 '_value_1': None,
# ...

# %%
loadInformation
vendorConfig
*preemption
*mlppIndicationStatus
currentConfig
singleButtonBarge
ownerUserName
